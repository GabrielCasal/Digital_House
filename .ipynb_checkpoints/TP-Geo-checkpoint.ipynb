# %%
# %matplotlib inline

import pandas as pd
import geopandas
import fiona
import rtree

pd.options.display.max_rows = 10

# %%
import fiona
import rtree

# %%
barrios = pd.read_csv("barrios.csv", encoding='latin1')

# %%
barrios.head(10)
# Out:
#                                                  WKT            BARRIO  \
# 0  POLYGON ((-58.4528200492791 -34.5959886570639,...         CHACARITA
# 1  POLYGON ((-58.4655768128541 -34.5965577078058,...          PATERNAL
# 2  POLYGON ((-58.4237529813037 -34.5978273383243,...      VILLA CRESPO
# 3  POLYGON ((-58.4946097568899 -34.6148652395239,...  VILLA DEL PARQUE
# 4  POLYGON ((-58.4128700313089 -34.6141162515854,...           ALMAGRO
# 5  POLYGON ((-58.4306058283309 -34.6070470885963,...         CABALLITO
# 6  POLYGON ((-58.4819203599833 -34.6242871724757,...  VILLA SANTA RITA
# 7  POLYGON ((-58.5034920611534 -34.6240324216321,...      MONTE CASTRO
# 8  POLYGON ((-58.525116079791 -34.613999981063,-5...        VILLA REAL
# 9  POLYGON ((-58.4452515823782 -34.6420397134706,...            FLORES
#
#    COMUNA     PERIMETRO          AREA
# 0    15.0   7725.695228  3.118101e+06
# 1    15.0   7087.513295  2.229829e+06
# 2    15.0   8132.699348  3.613584e+06
# 3    11.0   7705.389797  3.399596e+06
# 4     5.0   8537.901368  4.050752e+06
# 5     6.0  10990.964471  6.851029e+06
# 6    11.0   5757.752335  2.153691e+06
# 7    10.0   7361.036418  2.627481e+06
# 8    10.0   5070.965652  1.334146e+06
# 9     7.0  15772.425185  8.590784e+06

# %%
def from_wkt(df, wkt_column):
    import shapely.wkt
    df["coordinates"]= df[wkt_column].apply(shapely.wkt.loads)
    gdf = geopandas.GeoDataFrame(barrios, geometry='coordinates')
    return gdf

# %%
barrios = from_wkt(barrios, "WKT")

# %%
barrios.plot()

# %%
barrios.head()
# Out:
#                                                  WKT            BARRIO  \
# 0  POLYGON ((-58.4528200492791 -34.5959886570639,...         CHACARITA
# 1  POLYGON ((-58.4655768128541 -34.5965577078058,...          PATERNAL
# 2  POLYGON ((-58.4237529813037 -34.5978273383243,...      VILLA CRESPO
# 3  POLYGON ((-58.4946097568899 -34.6148652395239,...  VILLA DEL PARQUE
# 4  POLYGON ((-58.4128700313089 -34.6141162515854,...           ALMAGRO
#
#    COMUNA    PERIMETRO          AREA  \
# 0    15.0  7725.695228  3.118101e+06
# 1    15.0  7087.513295  2.229829e+06
# 2    15.0  8132.699348  3.613584e+06
# 3    11.0  7705.389797  3.399596e+06
# 4     5.0  8537.901368  4.050752e+06
#
#                                          coordinates
# 0  POLYGON ((-58.4528200492791 -34.5959886570639,...
# 1  POLYGON ((-58.4655768128541 -34.5965577078058,...
# 2  POLYGON ((-58.4237529813037 -34.5978273383243,...
# 3  POLYGON ((-58.4946097568899 -34.6148652395239,...
# 4  POLYGON ((-58.4128700313089 -34.6141162515854,...

# %%
mis_barrios = barrios[barrios.BARRIO.isin(["PALERMO", 'BELGRANO', 'RECOLETA'])]

# %%
mis_barrios.plot()

# %%
data = pd.read_csv("./DATA/properattilimpio.csv", encoding='latin1')

# %%
data.rename(columns={'lat' : 'latitud', 'lon' : 'longitud'}, inplace = True)

# %%
def from_x_y(df, x, y):
    from shapely.geometry import Point
    gdf = geopandas.GeoDataFrame(df,
                                crs={'init': 'epsg:4326'},
                                geometry=[Point(xy) for xy in zip(df[x], df[y])])
    return gdf

# %%
data = from_x_y(data, "longitud","latitud")

# %%
result=geopandas.sjoin(mis_barrios, data, how = "left")
# Out:
# C:\Users\juan\Anaconda3\lib\site-packages\geopandas\tools\sjoin.py:44: UserWarning: CRS of frames being joined does not match!
#   warn('CRS of frames being joined does not match!')
# C:\Users\juan\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2831: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)

# %%
result = result.drop(result.columns[[0, 2, 3, 4, 5]], axis=1)

# %%
result = result.set_index('index_right')

# %%
result.rename(columns={'BARRIO_left' : 'BARRIO', 'BARRIO_right' : 'SUBBARRIO'}, inplace = True)

# %%
result = from_x_y(result, "longitud","latitud")

# %%
result.to_csv("./DATA/pal-bel-rec.csv")

# %%
result
# Out:
#                BARRIO  Unnamed: 0     ID TIPO_PROPIEDAD  \
# index_right
# 3637          PALERMO       12689  12689      apartment
# 3638          PALERMO       12690  12690      apartment
# 10475         PALERMO       32143  32143      apartment
# 10490         PALERMO       32167  32167      apartment
# 2020          PALERMO        8196   8196      apartment
# ...               ...         ...    ...            ...
# 2578         RECOLETA        9961   9961      apartment
# 20417        RECOLETA       57729  57729      apartment
# 18362        RECOLETA       52793  52793      apartment
# 3434         RECOLETA       12067  12067      apartment
# 3435         RECOLETA       12068  12068      apartment
#
#                                    lat-lon    latitud   longitud     price  \
# index_right
# 3637               -34.5711496,-58.4232966 -34.571150 -58.423297  220000.0
# 3638               -34.5711496,-58.4232966 -34.571150 -58.423297  220000.0
# 10475               -34.5824159,-58.420049 -34.582416 -58.420049  390000.0
# 10490        -34.5876682151,-58.4150997693 -34.587668 -58.415100  330000.0
# 2020         -34.5699834561,-58.4346691662 -34.569983 -58.434669  790000.0
# ...                                    ...        ...        ...       ...
# 2578          -34.591817224,-58.4071244529 -34.591817 -58.407124  395000.0
# 20417              -34.5958568,-58.3876966 -34.595857 -58.387697  380000.0
# 18362                -34.596767,-58.397408 -34.596767 -58.397408  359000.0
# 3434               -34.5888723,-58.4002528 -34.588872 -58.400253  200000.0
# 3435               -34.5888723,-58.4002528 -34.588872 -58.400253  820000.0
#
#             currency  price_aprox_local_currency  \
# index_right
# 3637             USD                   3881790.0
# 3638             USD                   3881790.0
# 10475            USD                   6881355.0
# 10490            USD                   5822685.0
# 2020             USD                  13939155.0
# ...              ...                         ...
# 2578             USD                   6969577.5
# 20417            USD                   6704910.0
# 18362            USD                   6334375.5
# 3434             USD                   3528900.0
# 3435             USD                  14468490.0
#
#                                ...                      lavadero  balcon  \
# index_right                    ...
# 3637                           ...                             0       1
# 3638                           ...                             0       1
# 10475                          ...                             0       1
# 10490                          ...                             1       1
# 2020                           ...                             1       1
# ...                            ...                           ...     ...
# 2578                           ...                             0       1
# 20417                          ...                             1       1
# 18362                          ...                             1       0
# 3434                           ...                             0       1
# 3435                           ...                             0       1
#
#              terraza  sum  solarium  parrilla  a estrenar  subte cochera  \
# index_right
# 3637               1    1         0         0           0      1       1
# 3638               1    1         0         0           0      1       1
# 10475              0    0         0         0           0      0       1
# 10490              0    0         0         0           0      0       1
# 2020               1    1         1         1           0      0       1
# ...              ...  ...       ...       ...         ...    ...     ...
# 2578               1    1         0         0           0      1       0
# 20417              0    0         0         0           0      0       0
# 18362              0    0         0         0           0      0       1
# 3434               0    0         1         0           0      0       1
# 3435               1    0         1         0           0      0       1
#
#                                               geometry
# index_right
# 3637            POINT (-58.4232966 -34.57114960000001)
# 3638            POINT (-58.4232966 -34.57114960000001)
# 10475                   POINT (-58.420049 -34.5824159)
# 10490        POINT (-58.41509976930001 -34.5876682151)
# 2020             POINT (-58.4346691662 -34.5699834561)
# ...                                                ...
# 2578              POINT (-58.4071244529 -34.591817224)
# 20417                  POINT (-58.3876966 -34.5958568)
# 18362                    POINT (-58.397408 -34.596767)
# 3434            POINT (-58.40025279999999 -34.5888723)
# 3435            POINT (-58.40025279999999 -34.5888723)
#
# [3885 rows x 41 columns]

# %%
muestra = data.sample(200)

# %%
import folium
m = folium.Map([-34.606359, -58.443863], zoom_start=11, tiles="OpenStreetMap")
folium.GeoJson(mis_barrios.to_json()).add_to(m)
folium.GeoJson(muestra.to_json()).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
